# %%
import numpy as np
import math
x = np.random.uniform(-100,100)
y = np.random.uniform(-100,100)
eeta = 0.005
iterations = 200
for _ in range(iterations):
    slopex=6*x
    slopey=-5*math.exp(-y)
    x_stepLength=-eta*x_slope
    y_stepLength=-eta*y_slope
    x, y = x + x_stepLength, y + y_stepLength
x, y = round(x), round(y)
objFunc = 3 * x**2 + 5 * math.exp(-y) + 10
print('Final value of x =', x)
print('Final value of y =', y)
print('Objective Function value =', objFunc)
# Out:
# Initial value of x : 39.99628818870116
# Initial value of y : 83.91309076964794
# Final value of x = 0
# Final value of y = 84
# Objective Function value = 10.0

# %%
from PIL import Image
img = Image.open('Assets/Assignment3.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=756x1024 at 0x7F20800D1160>
